# %% [markdown]
# # **Questions and Answers**
#
# ## **GENERIC**
#
# **1) How many branches are within the dataset?**
# * There are 3 distinct branches within the dataset: A, B, and C.
#
# **2) How many cities are within the dataset?**
# * There are 3 unique cities within the dataset: Yangon, Naypyitaw, and Mandalay.
#
# **3) How many product lines are within the dataset?**
# * There are 6 product lines within the dataset: food and beverages, health and beauty, sports and travel, fashion accessories, home and lifestyle and electronic accessories.
#
# **4) How many customer types are within in the dataset?**
# * There are 2 customer types within the dataset: normal and member.
#
# **5) How many payment methods are within the dataset?**
# * There are 3 payment methods within the dataset: credit card, ewallet and cash.
#
# **6) Which city is associated with which branch?**
# * Yangon is associated with branch A, Mandalay is associated with branch B, and Naypyitaw is associated with branch C.
#
#
# ## **PRODUCTS**
# **1) Which product line had the most sales?**
# * The product line with the most sales was fashion accessories with 178 total sales. The product with the least number of sales was health and beauty.
#
# **2) Which product line has the largest revenue?**
# * The product line that has the largest revenue is food and beverages with a total revenue of $56144.96.
#
# **3) What is the average rating for each product line?**
# * The average rating for each product line can be observed from the table below
#
# | Product line | average rating |
# | --------- | --------- |
# | Food and beverages | 7.11 |
# | Fashion accessories | 7.03 |
# | Health and beauty | 6.98 |
# | Electronic accessories | 6.91 |
# | Sports and travel | 6.86 |
# | Home and lifestyle | 6.84 |
#
# **4) What is the most common product line for each gender?**
# * The most common product like for females is fashion accessories while the most common for males is health and beauty. One this we can note is that while males most common product line is health and beauty, the least common for females is health and beauty.
#
# **5) Which product lines were above the average sales for the entire dataset?**
# * The average sales for the entire dataset is $322.50. When examining the data, the 4 product lines that have an average sale over this amount are food and beverages with $322.67, health and beauty with $323.54, sports and travel with $330.90 and home and lifestyle with $336.64.
#
# ## **SALES**
# **1) What is the total revenue for each month?**
# * The total revenue for each month is: January => $116292.11, February => $95727.58 and March $108867.38. The month with the lowest revenue was February.
#
# **2) Which month has the largest COGS?**
# * The month that has the largest cost of goods sold is January with $110754.16 followed by March with $103683 and finally have February with $91168.93. From both the total revenue and COGS, we notice that February seemed like a down month for Walmart compared to the other 2 months.
#
# **3) Which city has the largest revenue?**
# * The city with the largest revenue is Naypyitaw with $110490.93 followed by Yangon and Mandalay with $105861.21 and $104534.93 respectively. There is not that much a revenue difference between the cities especially with Yangon and Mandalay.
#
# **4) Which product line had the largest VAT?**
# * The product with the largest value added tax is home and lifestyle where as the lowest product is fashion accessories.
#
# **5) Which branch sold more products than average products sold?**
# * Branch A sold the most products that were above the average product sold.
#
# **6) During which time of day are the number of sales the largest during each weekdays?**
# * For Monday the largest number of sales is during the evening, Tuesday is evening, Wednesday is Afternoon, Thursday is evening and Friday is afternoon. Note that none of the weekdays have morning as the largest number of sales during the time of day, this is probably due to the fact that people are working during the morning so they aren't able to visit Walmart.
#
# **7) During which time of day are the number of sales the largest during each weekend?**
# * For Saturday and Sunday the largest number of sales occur during the evening. This is surprising because I'd assume that people would do their shopping on a weekend morning but realistically, the number of sales on a weekend morning is not even remotely close to the number of sales during the afternoon and evening during the weekend.
#
# **8) Which city has the largest tax percent / VAT (Value Added Tax)?**
# * The city of Naypyitaw has the largest VAT of 16.1%.
#
# **9) What is the average gross income for each branch based off the time of day?**
# * For branch A t he largest average gross income is during the afternoon, followed by afternoon for branch B and finally evening for branch C. It's also apparent that branch C appears to have the largest average gross income amongst all branches regardless of the time of day. (Maybe this has to do with Naypyitaw having the largest VAT?)
#
# **10) What is the average sales based of each payment method?**
# * It appears cash has the largest average sales compared to every other payment method which is odd because typically for big purchases people would pay using credit cards or ewallets. This is something we may look further into.
#
# **11)Count the total amount of times a sale from each branch was above the average gross income**
# * 130 times for branch A, 132 times for branch B and 138 times for branch C.
#
# ## **CUSTOMER**
# **1) How many customers are within each customer type?**
# * There are 499 members while there are 496 normal customers. There seems to be an even distribution in customer types within this dataset.
#
# **2) How many members are in each branch?**
# * There are 164 members in branch A, 167 in branch B and 168 in branch C. Again, there appears to be a uniform distribution amongst members within each branch.
#
# **3) Which payment method was used the most amongst the customers?**
# * Cash appears to be the most common payment method amongst customers. This could also attribute to the fact that cash was the payment method that was used for the largest average sales amounts.
#
# **4) What is the gender distribution amongst the customers?**
# * The gender distribution amongst customers is nearly dead even with only 1 more male customer compared to female customers.
#
# **5) What is the gender distribution per branch?**
# * For branch B, the gender distribution is relatively even compared to the other branches as there are only 9 more males compared to females. For branch A there are 19 more males compared to females and for branch C there are 27 more females compared to males.
#
# **6) Which of the customer types brings the most revenue?**
# * As expected, members bring the most revenue with $163625.47 compared to normal customers bringing in $157261.60 worth of revenue.
#
# **7) Which time of the day do customers give most ratings?**
# * Customers appear to provide the highest average rating of 7.02 during the afternoon, however it doesn't seem to be a drastic difference compared to the lowest average rating which is during the evening of 6.91. (Only a 0.11 difference)
#
# **8) Which time of the day do customers give most ratings per branch?**
# * For branch A, customers give the highest ratings during the afternoon. For branch B, customers give the highest rating during the morning and for branch C customers give the highest rating during the evening.
#
# **9) Which day of the week has the best avg ratings?**
# * Customers provide the largest average rating during Monday where as the lowest is on Wednesdays. Maybe we can look to factors why this could be? (Who works during these days? Any special promotions on Mondays?)
#
# **10) Which day of the week has the best average ratings per branch?**
# * For branch A => Friday, branch B => Monday, branch C => Saturday
#
# **11) Sort the customers ratings into 3 unique bins where 0-5 ==> 'Poor', 5-7 ==> 'Decent', 7-10 ==> 'Great' and count the total number of customers in each bin.**
# * There were 476 `great` reviews, 345 `decent` reviews and 174 `poor` reviews.
